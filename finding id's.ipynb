# %%
a = 5
b = a
id(a)
# Out:
# 140731405870120

# %%
id(b)
# Out:
# 140731405870120

# %%
a="erherherh"
b=a
c=b
sys.getrefcount(a)
# Out:
# 4

# %%
a = 6
b = 6
id(a)
# Out:
# 140731405870152

# %%
id(b)
# Out:
# 140731405870152

# %%
a = 8
b = 8
id(a)
# Out:
# 140731405870216

# %%
id(b)
# Out:
# 140731405870216

# %%
a = 9
b = 9
id(a)
# Out:
# 140731405870248

# %%
id(b)
# Out:
# 140731405870248

# %%
a = -5
b = -5
id(a)
# Out:
# 140731405869800

# %%
id(b)
# Out:
# 140731405869800

# %%
a = "kcc_gr_noida"
b = "kcc_gr_noida"
id(a)
# Out:
# 1834368058096

# %%
id(b)
# Out:
# 1834368058096

# %%
a = [1,2,3]
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
id(a)
# Out:
# 1834367900224
