# %%
c = ["who", "is", "she"]
" ".join(c)
# Out:
# 'who is she'

# %%
a = "hi my name is unity"
a.replace("unity", "unnati")
# Out:
# 'hi my name is unnati'

# %%
name = "            unnati                   "
name.strip()
# Out:
# 'unnati'

# %%
L = [0, 1, 2, "HWLL"]
print(L[3])
# Out:
# HWLL

# %%
L3 = [1, 2, 3,[4, 5]]
print(L3[-1] [1])
# Out:
# 5

# %%
L = [0,1,2,3,4,5,6]
L[2] = 900000000000000000
print(L)
# Out:
# [0, 1, 900000000000000000, 3, 4, 5, 6]

# %%
L = [1,2,3,4]
L.append([0,1,234])
print(L)
# Out:
# [1, 2, 3, 4, [0, 1, 234]]

# %%
L =[0,1,2]
L.extend("hi")
print(L)
# Out:
# [0, 1, 2, 'h', 'i']

# %%
L = [0,1,2,3,4]
L.insert(3,"hi")
print(L)
# Out:
# [0, 1, 2, 'hi', 3, 4]

# %%
L = [0, 1,2, 3]
del(L[1])
print(L)
# Out:
# [0, 2, 3]

# %%
L = [0,1,4,7890]
L.pop()
print(L)
# Out:
# [0, 1, 4]

# %%
1 in L
# Out:
# True

# %%
l = [1,2,3,4,4,5,6,7]
len(l)
# Out:
# 8

# %%
max(l)
# Out:
# 7

# %%
sorted(l)
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7]

# %%
sorted(l, reverse = True)
# Out:
# [7, 6, 5, 4, 4, 3, 2, 1]

# %%
a = "how are you"
print(a.split())
# Out:
# ['how', 'are', 'you']

# %%
for i in a.split():
    print(i.capitalize())
    L.append(i.capitalize())
print(L) 
print(" ".join(L))
# Out:
# How
# Are
# You
# [0, 1, 4, 'You', 'You', 'How', 'How', 'Are', 'You']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3     L.append(i.capitalize())
#       4 print(L)
# ----> 5 print(" ".join(L))
#
# TypeError: sequence item 0: expected str instance, int found

# %%
L.append(i.capitalize())
print(L)
print(" ".join(L))
# Out:
# [0, 1, 4, 'You', 'You']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 L.append(i.capitalize())
#       2 print(L)
# ----> 3 print(" ".join(L))
#
# TypeError: sequence item 0: expected str instance, int found

# %%
T = (1,2,3,4,5,6)
T[3] = 99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 T = (1,2,3,4,5,6)
# ----> 2 T[3] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
s = {1,1,2,2,3,4,3,4,5,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
d = {"name":"unnati", "clg" : "kcc"}
print(d["name"])
# Out:
# unnati

# %%
#2D Dictionary
d = {"name":"unnati", "college":"kcc", "marks":{"maths":55,"english":99,"evs":89}}
d["marks"]["maths"] = 87
print(d)
# Out:
# {'name': 'unnati', 'college': 'kcc', 'marks': {'maths': 87, 'english': 99, 'evs': 89}}

# %%
d = {"name":"unnati", "college":"kcc", "marks":{"maths":55,"english":99,"evs":89}}
del d["marks"]
print(d)
# Out:
# {'name': 'unnati', 'college': 'kcc'}

# %%
for i in d:
    print(i)
# Out:
# name
# college

# %%
len(d)
# Out:
# 2

# %%
d.keys()
# Out:
# dict_keys(['name', 'college'])

# %%
d.values()
# Out:
# dict_values(['unnati', 'kcc'])
