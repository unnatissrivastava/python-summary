# %%
a = 20
while(a<50):
    a += 2
    print("unnati")
# Out:
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati
# unnati

# %%
a = 0
while(a < 3):
    a += 1
    print("hi")
# Out:
# hi
# hi
# hi

# %%
for i in range(1,5):
    for j in range(i):
        print (i, end=' ')
    print( )
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
i = 1

while True:
    if i%10 == 0:
        break
        
    print(i, end = " ")
    i += 1

# %%
i = 1

while True:
    if i%10 == 0:
        break
        
    print(i, end = " ")
    i += 1

# %%
i = 1

while True:
    if i % 10 == 0:
        break

    print(i, end=" ")
    i += 1

print()
