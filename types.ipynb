# %%
colour = input("Enter a color:")
print(colour)
# Out:
# Enter a color: red
# red

# %%
colour = input("enter: ")
print("COLOUR IS: ", colour)
# Out:
# enter:  red
# COLOUR IS:  red

# %%
a = "Hello World"
b = 10
c = 11.22
d = ("Geeks", "for", "Geeks")
e = ["Geeks", "for", "Geeks"]
f = {"Geeks": 1, "for":2, "Geeks":3}


print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>

# %%
a = ("10")
print(type(a))
# Out:
# <class 'str'>

# %%
x, y, z = ("unnati", "is", "a 10/10")
print(x, y, z)
# Out:
# unnati is a 10/10

# %%
a, b = (10, 5)
a, b = b, a
print(a, b)
# Out:
# 5 10
