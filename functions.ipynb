# %%
def ab(number):
    if type(number) == int:
        if number % 2 == 0:
            return "yay"
        else:
            return "nay"
    else:
        return "not allowed"
for i in range(1,11):
    print(ab(i))
# Out:
# nay
# yay
# nay
# yay
# nay
# yay
# nay
# yay
# nay
# yay

# %%
print(5)
# Out:
# 5

# %%
def power(a=1, b=1):
    return a**b

power(2,3)
# Out:
# 8

# %%
power(4,5)
# Out:
# 1024

# %%
def fun():
    print("hii")

    fun()

# %%
def f(y):
    x = 1
    x += 1
    print(x)

x = 5
f(x)

print(x)
# Out:
# 2
# 5
