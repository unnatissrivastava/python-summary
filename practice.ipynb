# %%
class fraction:
    def __init__(self,n,d):
        self.n = n
        self.d = d
    def __str__(self):
        return"{}/{}".format(self.n, self.d)

    def __add__(self,other):
        self.n= self.n * other.d + other.n * self.d
        self.d= self.d * other.d
        return"{}/{}".format(self.n, self.d)

x = fraction(3,4)
y = fraction(5,6)
print(x)
print(x + y)
# Out:
# 3/4
# 38/24

# %%
#instance variable: variable whose value is different for different object

# %%
#encapsulation
class Atm:

    def __init__(self):

        self.__pin = ""
        self.__balance = 0

        self.__menu()  

    def __menu(self):
        user_input = input("""
                    Hello, How would you like to procees?
                      1. ENTER 1 TO CREATE PIN
                      2. ENTER 2 TO DEPOSIT
                      3. ENTER 3 TO WITHDRAW
                      4. ENTER 4 TO CHECK BALANCE
                      5. ENTER 5 TO EXIT
""")
        
        if user_input == "1":
            self.create_pin()
            
        elif user_input == "2":
            self.deposit()
            
        elif user_input == "3":
            self.withdraw()
            
        elif user_input == "4":
            self.check_balance()
            
        elif user_input == "5":
            print("thanks")
            return
            
        else:
            print("bye")

        self.__menu()

    def create_pin(self):
        self.__pin = input("enter your pin: ")
        print("pin set successfully")

    def deposit(self):
        temp = input("enter your pin: ")
            
        if temp == self.__pin:
            amount = int(input("enter the amount: "))
            self.__balance = self.__balance + amount
            print("deposited succesfully!!")
        else:
            print("incorrect pin")

    def withdraw(self):
        temp = input("enter your pin: ")
        if temp == self.__pin:
            amount = int(input("enter the amount: "))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print("operation successful")
            else:
                print("insufficient funds")
        else:
            print("invalid pin")

    def check_balance(self):
        temp = input("enter your pin: ")
        if temp == self.__pin:
            print(self.__balance)
        else:
            print("invalid pin")

sbi = Atm()
# Out:
#                     Hello, How would you like to procees?
#                       1. ENTER 1 TO CREATE PIN
#                       2. ENTER 2 TO DEPOSIT
#                       3. ENTER 3 TO WITHDRAW
#                       4. ENTER 4 TO CHECK BALANCE
#                       5. ENTER 5 TO EXIT
#  1
# enter your pin:  1234
# pin set successfully
#                     Hello, How would you like to procees?
#                       1. ENTER 1 TO CREATE PIN
#                       2. ENTER 2 TO DEPOSIT
#                       3. ENTER 3 TO WITHDRAW
#                       4. ENTER 4 TO CHECK BALANCE
#                       5. ENTER 5 TO EXIT
#  2
# enter your pin:  1234
# enter the amount:  4500
# deposited succesfully!!
#                     Hello, How would you like to procees?
#                       1. ENTER 1 TO CREATE PIN
#                       2. ENTER 2 TO DEPOSIT
#                       3. ENTER 3 TO WITHDRAW
#                       4. ENTER 4 TO CHECK BALANCE
# ...

# %%
class Customer:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
    def greet(customer):
        if customer.gender == "male":
            print("Hello", customer.name, "s`ir")
        else:
            print("Hello", customer.name, "mam")
        
        
cust = Customer("unnati","female")
cust.greet()
# Out:
# Hello unnati mam

# %%
#pass by reference
def change(L):
    print(id(L))
    L.append(5)
    print(id(L))

L1 = [1,2,3,4]
print(id(L1))
print(L1)
change(L1[:])
print(L1)
# Out:
# 2535228989632
# [1, 2, 3, 4]
# 2535228896448
# 2535228896448
# [1, 2, 3, 4]

# %%
#collection of objects
class a:
    def __init__(self, name, age):
        self.name = name
        self.age = age
c1 = a("unnati", 19)
c2 = a("soham", 11)

L = [c1,c2]

for i in L:
    print(i.age)
# Out:
# 19
# 11

# %%
#static variables and methods
class Atm:
    counter = 1

    def __init__(self):

        self.__pin = ""
        self.__balance = 0
        self.sno = Atm.counter
        Atm.counter = Atm.counter + 1

        self.__menu()  

    def __menu(self):
        user_input = input("""
                    Hello, How would you like to procees?
                      1. ENTER 1 TO CREATE PIN
                      2. ENTER 2 TO DEPOSIT
                      3. ENTER 3 TO WITHDRAW
                      4. ENTER 4 TO CHECK BALANCE
                      5. ENTER 5 TO EXIT
""")
        
        if user_input == "1":
            self.create_pin()
            
        elif user_input == "2":
            self.deposit()
            
        elif user_input == "3":
            self.withdraw()
            
        elif user_input == "4":
            self.check_balance()
            
        elif user_input == "5":
            print("thanks")
            return
            
        else:
            print("bye")

        #self.__menu()
    def get_counter(self):
        return Atm.__counter

    def set_counter(self, new):
        if type(new) == int:
            Atm.counter = new
        else:
            print("not allowed")

    def create_pin(self):
        self.__pin = input("enter your pin: ")
        print("pin set successfully")

    def deposit(self):
        temp = input("enter your pin: ")
            
        if temp == self.__pin:
            amount = int(input("enter the amount: "))
            self.__balance = self.__balance + amount
            print("deposited succesfully!!")
        else:
            print("incorrect pin")

    def withdraw(self):
        temp = input("enter your pin: ")
        if temp == self.__pin:
            amount = int(input("enter the amount: "))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print("operation successful")
            else:
                print("insufficient funds")
        else:
            print("invalid pin")

    def check_balance(self):
        temp = input("enter your pin: ")
        if temp == self.__pin:
            print(self.__balance)
        else:
            print("invalid pin")

sbi = Atm()
Atm.counter

#init is a constructor meaning iske andar ka code automatically execute hota h when a class' object is made

# %% [raw]
# > iteration:general term for taking each item of something, one after another, anytime u use a loop, explicit, or implicit to go over a group of items, that is iteration
#
# > iterable: an object over which we can perform iteration
#
# > iterator: an object that allows iteration
#
# > every iterator is an iterable but not vice versa

# %%
L = [1,2,3]
type(iter(L))
# Out:
# list_iterator

# %%
num = [1,2,3]
for i in num:
    print(i)
# Out:
# 1
# 2
# 3

# %%
n = [1,2,3]
a = iter(n)

next(a)
next(a)
# Out:
# 2

# %%
def myloop(iterable):
    iterator = iter(iterable)
    while True:
        try:
            print(next(iterator))
        except StopIteration:
            break

# %%
a = [1,2,3]
b = range(1,11)
c = (1,2,3)
d = {1,2,3}
e = {0:1, 1:1}
myloop(e)
# Out:
# 0
# 1

# %%
class fraction:
    def __init__(self, n, d):
        self.n = n
        self.d = d
    def __str__(self):
        return "{}/{}".format(self.n,self.d)

x = fraction(20,5)
print(x)
# Out:
# 20/5

# %%
class fraction:
    def __init__(self, d, n):
        self.n = n
        self.d = d

    def __str__(self):
        return "{}/{}".format(self.n, self.d)
    def __add__(self, other):
        n = self.n * other.d + other.n * self.d
        d = self.d * other.d
        return "{}/{}".format(n, d)

    def __mul__(self, other):
        n = self.n * other.n
        d = self.d *other.d
        return "{}/{}".format(n,d)
x = fraction(8,9)
y = fraction (6,7)
print(x*y)
# Out:
# 63/48

# %%
class Atm:

    def __init__(self):

        self.__pin = ""
        self.__balance = 0

        self.__menu()  

    def __menu(self):
        user_input = input("""
                    Hello, How would you like to procees?
                      1. ENTER 1 TO CREATE PIN
                      2. ENTER 2 TO DEPOSIT
                      3. ENTER 3 TO WITHDRAW
                      4. ENTER 4 TO CHECK BALANCE
                      5. ENTER 5 TO EXIT
""")
        
        if user_input == "1":
            self.create_pin()
            
        elif user_input == "2":
            self.deposit()
            
        elif user_input == "3":
            self.withdraw()
            
        elif user_input == "4":
            self.check_balance()
            
        elif user_input == "5":
            print("thanks")
            return
            
        else:
            print("bye")

        self.__menu()

    def create_pin(self):
        self.__pin = input("enter your pin: ")
        print("pin set successfully")

    def deposit(self):
        temp = input("enter your pin: ")
            
        if temp == self.__pin:
            amount = int(input("enter the amount: "))
            self.__balance = self.__balance + amount
            print("deposited succesfully!!")
        else:
            print("incorrect pin")

    def withdraw(self):
        temp = input("enter your pin: ")
        if temp == self.__pin:
            amount = int(input("enter the amount: "))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print("operation successful")
            else:
                print("insufficient funds")
        else:
            print("invalid pin")

    def check_balance(self):
        temp = input("enter your pin: ")
        if temp == self.__pin:
            print(self.__balance)
        else:
            print("invalid pin")

sbi = Atm()
# Out:
#                     Hello, How would you like to procees?
#                       1. ENTER 1 TO CREATE PIN
#                       2. ENTER 2 TO DEPOSIT
#                       3. ENTER 3 TO WITHDRAW
#                       4. ENTER 4 TO CHECK BALANCE
#                       5. ENTER 5 TO EXIT
#  1
# enter your pin:  1234
# pin set successfully
#                     Hello, How would you like to procees?
#                       1. ENTER 1 TO CREATE PIN
#                       2. ENTER 2 TO DEPOSIT
#                       3. ENTER 3 TO WITHDRAW
#                       4. ENTER 4 TO CHECK BALANCE
#                       5. ENTER 5 TO EXIT
#  5
# thanks

# %%
#pass by reference
class cust:
    def __init__(self, name):
        self.name = name
def greet(cust):
    print(id(cust))
    cust.name = 'unnati'
    print(cust.name)
    print(id(cust.name))
cust = cust("soham")
print(id(cust))
greet(cust)
print(cust.name)
# Out:
# 2118320636320
# 2118320636320
# unnati
# 2118314273136
# unnati

# %%
def change(x):
    x = 100
a = 5
change(a)
print(a)
# Out:
# 5

# %%
class dog:
    def __init__(self, name):
        self.name = name
    def rename(dog):
