# %%
#class relationship - aggregation & inheritance
# aggregation [(has - a) relationship] & inheritance [(is - a) relationship]

# %%
class customer:
    def __init__(self, name, gender, address):
        self.name = name
        self.gender = gender
        self.address = address
    def edit_profile(self, new_name, new_city, new_pin, new_state):
        self.name = new_name
        self.address.change_address(new_city, new_pin, new_state)

class address:
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode = pincode
        self.state = state
    def change_address(self, new_city, new_pin, new_state):
        self.city = new_city
        self.pincode = new_pin
        self.state = new_state

        
add = address("delhi", 201310, "del")
cust = customer("unnati", "gender", add)

cust.edit_profile("Unnati V", "Noida", 201301, "UP")

print(cust.address.pincode)
# Out:
# 201301

# %%
#inheritance: ek class dusri class ke features (methods aur attributes) ko use kar sakti hai.
#Parent class ke functions ko Child class bina dobara likhe use kar sakti hai.
class user:
    def login(self):
        print("login")
    def register(self):
        print("register")

class student(user):
    def enroll(self):
        print("enroll")
    def review(self):
        print("review")
stu1 = student()
stu1.login()
stu1.register()
stu1.enroll()
stu1.review()
# Out:
# login
# register
# enroll
# review

# %%
#polymorphism
class phone:
    def __init__(self, price, brand, camera):
        print("inside phone constructor")
        self.price = price
        self.__brand = brand
        self.camera = camera

    def buy(self):
        print("buying phone")
        

class mobile(phone):
     def buy(self):
        print("buying mobile")
s = mobile(88900, "samsung", 13)
s.buy()
# Out:
# inside phone constructor
# buying mobile

# %%
#super(): used to envoke/call parent's methods
